# %% [markdown]
# # Community Modeling with PyCoMo
# PyCoMo is a python package that allows for the modeling and simulation of microbial communities, focusing on their interactions, metabolism, and dynamics. PyCoMo provides a set of tools to simulate and analyze how different species in a community interact with each other, share resources, and contribute to the overall ecosystem's function. Here, we will use the representative organisms identified from the t-SNE clustering to build the community model.

# %%
# Installing necessary packages and importing libraries
# !pip install pycomo
# !pip install cobra
import pycomo
import pandas as pd
import os
import cobra
from cobra.io import read_sbml_model
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Collecting pycomo
#   Downloading pycomo-0.2.6-py3-none-any.whl.metadata (4.4 kB)
# Collecting cobra>=0.23.0 (from pycomo)
#   Downloading cobra-0.29.1-py2.py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from pycomo) (2.2.2)
# Collecting python-libsbml>=5.20.1 (from pycomo)
#   Downloading python_libsbml-5.20.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (532 bytes)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pycomo) (1.26.4)
# Collecting appdirs~=1.4 (from cobra>=0.23.0->pycomo)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting depinfo~=2.2 (from cobra>=0.23.0->pycomo)
#   Downloading depinfo-2.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting diskcache~=5.0 (from cobra>=0.23.0->pycomo)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from cobra>=0.23.0->pycomo) (1.0.0)
# Requirement already satisfied: httpx~=0.24 in /usr/local/lib/python3.10/dist-packages (from cobra>=0.23.0->pycomo) (0.27.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from cobra>=0.23.0->pycomo) (6.4.5)
# Collecting optlang~=1.8 (from cobra>=0.23.0->pycomo)
#   Downloading optlang-1.8.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: pydantic>=1.6 in /usr/local/lib/python3.10/dist-packages (from cobra>=0.23.0->pycomo) (2.9.2)
# Requirement already satisfied: rich>=8.0 in /usr/local/lib/python3.10/dist-packages (from cobra>=0.23.0->pycomo) (13.9.4)
# Collecting ruamel.yaml~=0.16 (from cobra>=0.23.0->pycomo)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting swiglpk (from cobra>=0.23.0->pycomo)
#   Downloading swiglpk-5.0.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->pycomo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->pycomo) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->pycomo) (2024.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra>=0.23.0->pycomo) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra>=0.23.0->pycomo) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra>=0.23.0->pycomo) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra>=0.23.0->pycomo) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra>=0.23.0->pycomo) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx~=0.24->cobra>=0.23.0->pycomo) (0.14.0)
# Requirement already satisfied: sympy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from optlang~=1.8->cobra>=0.23.0->pycomo) (1.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.6->cobra>=0.23.0->pycomo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.6->cobra>=0.23.0->pycomo) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.6->cobra>=0.23.0->pycomo) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->pycomo) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=8.0->cobra>=0.23.0->pycomo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=8.0->cobra>=0.23.0->pycomo) (2.18.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml~=0.16->cobra>=0.23.0->pycomo)
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=8.0->cobra>=0.23.0->pycomo) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.12.0->optlang~=1.8->cobra>=0.23.0->pycomo) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx~=0.24->cobra>=0.23.0->pycomo) (1.2.2)
# Downloading pycomo-0.2.6-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 3.5 MB/s eta 0:00:00
# Downloading cobra-0.29.1-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.2 MB/s eta 0:00:00
# Downloading python_libsbml-5.20.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 45.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading depinfo-2.2.0-py3-none-any.whl (24 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.9 MB/s eta 0:00:00
# Downloading optlang-1.8.2-py2.py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 kB 13.7 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 10.8 MB/s eta 0:00:00
# Downloading swiglpk-5.0.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 53.5 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 39.4 MB/s eta 0:00:00
# Installing collected packages: swiglpk, python-libsbml, appdirs, ruamel.yaml.clib, diskcache, depinfo, ruamel.yaml, optlang, cobra, pycomo
# Successfully installed appdirs-1.4.4 cobra-0.29.1 depinfo-2.2.0 diskcache-5.6.3 optlang-1.8.2 pycomo-0.2.6 python-libsbml-5.20.4 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.12 swiglpk-5.0.12
# Requirement already satisfied: cobra in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: appdirs~=1.4 in /usr/local/lib/python3.10/dist-packages (from cobra) (1.4.4)
# Requirement already satisfied: depinfo~=2.2 in /usr/local/lib/python3.10/dist-packages (from cobra) (2.2.0)
# Requirement already satisfied: diskcache~=5.0 in /usr/local/lib/python3.10/dist-packages (from cobra) (5.6.3)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from cobra) (1.0.0)
# Requirement already satisfied: httpx~=0.24 in /usr/local/lib/python3.10/dist-packages (from cobra) (0.27.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from cobra) (6.4.5)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from cobra) (1.26.4)
# Requirement already satisfied: optlang~=1.8 in /usr/local/lib/python3.10/dist-packages (from cobra) (1.8.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from cobra) (2.2.2)
# Requirement already satisfied: pydantic>=1.6 in /usr/local/lib/python3.10/dist-packages (from cobra) (2.9.2)
# Requirement already satisfied: python-libsbml~=5.19 in /usr/local/lib/python3.10/dist-packages (from cobra) (5.20.4)
# Requirement already satisfied: rich>=8.0 in /usr/local/lib/python3.10/dist-packages (from cobra) (13.9.4)
# Requirement already satisfied: ruamel.yaml~=0.16 in /usr/local/lib/python3.10/dist-packages (from cobra) (0.18.6)
# Requirement already satisfied: swiglpk in /usr/local/lib/python3.10/dist-packages (from cobra) (5.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx~=0.24->cobra) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx~=0.24->cobra) (0.14.0)
# Requirement already satisfied: sympy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from optlang~=1.8->cobra) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->cobra) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->cobra) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->cobra) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.6->cobra) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.6->cobra) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.6->cobra) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=8.0->cobra) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=8.0->cobra) (2.18.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml~=0.16->cobra) (0.2.12)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=8.0->cobra) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->cobra) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.12.0->optlang~=1.8->cobra) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx~=0.24->cobra) (1.2.2)
# 2024-12-04 18:12:32,771 - pycomo - INFO - Logger initialized.
# INFO:pycomo:Logger initialized.
# 2024-12-04 18:12:37,709 - pycomo - INFO - Utils Logger initialized.
# INFO:pycomo:Utils Logger initialized.
# 2024-12-04 18:12:37,715 - pycomo - INFO - Multiprocess Logger initialized.
# INFO:pycomo:Multiprocess Logger initialized.

# %% [markdown]
# # Creating a community model
# The creation of a community model consists of 3 steps:
# 1. Loading the member models
# 2. Preparing the member models for merging
# 3. Creating a community model

# %%
# ### Loading the member models ###

from google.colab import drive
drive.mount('/content/drive')

# Load the CSV file
df = pd.read_csv("/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/representative_organisms.csv")
representative_organisms = df["Organism"].tolist()  # Convert back to a list
print(representative_organisms)
# Out:
# Mounted at /content/drive
# ['Streptococcus_anginosus_1_2_62CV', 'Bacteroides_fragilis_NCTC_9343', 'Streptococcus_thoraltensis_DSM_12221', 'Shigella_sonnei_Ss046', 'Sulfolobus_solfataricus_P2', 'Porphyromonas_uenonis_60_3', 'Clostridium_bartlettii_DSM_16795']

# %%
# function to store the organism name and the model path as a dictionary
def import_models(file_path, extension='.xml'):
  models={}
  for organism_id in representative_organisms:
    file_name = organism_id
    models[file_name] = file_path + organism_id + extension

  return models

file_path = '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/'
models=import_models(file_path)
models
# Out:
# {'Streptococcus_anginosus_1_2_62CV': '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/Streptococcus_anginosus_1_2_62CV.xml',
#  'Bacteroides_fragilis_NCTC_9343': '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/Bacteroides_fragilis_NCTC_9343.xml',
#  'Streptococcus_thoraltensis_DSM_12221': '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/Streptococcus_thoraltensis_DSM_12221.xml',
#  'Shigella_sonnei_Ss046': '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/Shigella_sonnei_Ss046.xml',
#  'Sulfolobus_solfataricus_P2': '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/Sulfolobus_solfataricus_P2.xml',
#  'Porphyromonas_uenonis_60_3': '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/Porphyromonas_uenonis_60_3.xml',
#  'Clostridium_bartlettii_DSM_16795': '/content/drive/My Drive/AGORA/CurrentVersion/AGORA_1_03/AGORA_1_03_sbml/Clostridium_bartlettii_DSM_16795.xml'}

# %%
# Loading the models with inbuilt load_named_model function and storing them as a dictionary
loaded_named_models = []
for model in models.keys():
  named_models = pycomo.load_named_model(file_path + model + ".xml")
  loaded_named_models.append(named_models)

named_models = dict(loaded_named_models)
named_models
# Out:
# {<Model M_Streptococcus_anginosus_1_2_62CV__44____32__AGORA__32__version__32__1__46__03 at 0x79ceccc074f0>: 'Streptococcus_anginosus_1_2_62CV',
#  <Model M_Bacteroides_fragilis_NCTC_9343__44____32__AGORA__32__version__32__1__46__03 at 0x79cecd0e0b80>: 'Bacteroides_fragilis_NCTC_9343',
#  <Model M_Streptococcus_thoraltensis_DSM_12221__44____32__AGORA__32__version__32__1__46__03 at 0x79cecc241660>: 'Streptococcus_thoraltensis_DSM_12221',
#  <Model M_Shigella_sonnei_Ss046__44____32__AGORA__32__version__32__1__46__03 at 0x79cecc999a20>: 'Shigella_sonnei_Ss046',
#  <Model M_Sulfolobus_solfataricus_P2__44____32__AGORA__32__version__32__1__46__03 at 0x79cecb7613c0>: 'Sulfolobus_solfataricus_P2',
#  <Model M_Porphyromonas_uenonis_60_3__44____32__AGORA__32__version__32__1__46__03 at 0x79cec9b65720>: 'Porphyromonas_uenonis_60_3',
#  <Model M_Clostridium_bartlettii_DSM_16795__44____32__AGORA__32__version__32__1__46__03 at 0x79cec9928f70>: 'Clostridium_bartlettii_DSM_16795'}

# %% [markdown]
# <p align="justify">
#
# One of the requirements for a community metabolic model is a common biomass function.Let's check if the biomass function is the objective in all the models.</p>
#
# **Investigating the objective function**

# %%
for model in named_models.keys():
    print(model.objective)
# Out:
# Maximize
# 1.0*biomass528 - 1.0*biomass528_reverse_17df4
# Maximize
# 1.0*biomass345 - 1.0*biomass345_reverse_e128f
# Maximize
# 1.0*biomass109 - 1.0*biomass109_reverse_00b6a
# Maximize
# 1.0*biomass355 - 1.0*biomass355_reverse_0f45b
# Maximize
# 1.0*biomass249 - 1.0*biomass249_reverse_b6f37
# Maximize
# 1.0*biomass368 - 1.0*biomass368_reverse_fafd3
# Maximize
# 1.0*biomass524 - 1.0*biomass524_reverse_2f2dd

# %% [markdown]
# <p align="justify">According of above results, we can confirm that all the model organisms have the biomass reaction as the objective expression.
#
# With the models loaded, the next step is preparing them for merging. This is done by creating SingleOrganismModel objects. Using them, the models will be formatted for compliance with the SBML format. Further, an exchange compartment will be generated under the name _medium_.</p>

# %%
single_org_models = []
for model, name in named_models.items():
    print(name)
    single_org_model = pycomo.SingleOrganismModel(model, name)
    single_org_models.append(single_org_model)
# Out:
# Streptococcus_anginosus_1_2_62CV
# Bacteroides_fragilis_NCTC_9343
# Streptococcus_thoraltensis_DSM_12221
# Shigella_sonnei_Ss046
# Sulfolobus_solfataricus_P2
# Porphyromonas_uenonis_60_3
# Clostridium_bartlettii_DSM_16795

# %% [markdown]
# **Creating a community model**
#
# <p align="justify">With the member models prepared, the community model can be generated. The first step is to create a CommunityModel objects from the member models.</p>

# %%
# ### Creating a community model ###
community_name = "Representative_Gut_Microbiome"
com_model_obj = pycomo.CommunityModel(single_org_models, community_name)
com_model_obj.model
# Out:
# 2024-12-04 18:42:57,496 - pycomo - INFO - No community model generated yet. Generating now:
# INFO:pycomo:No community model generated yet. Generating now:
# 2024-12-04 18:42:57,663 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# INFO:pycomo:Note: no products in the objective function, adding biomass to it.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# 2024-12-04 18:43:04,072 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# INFO:pycomo:Note: no products in the objective function, adding biomass to it.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# 2024-12-04 18:43:08,236 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite pb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite pb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,243 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite hg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite hg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,250 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite mn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite mn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,252 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite indole. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite indole. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,256 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite cu2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite cu2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,260 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite mg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite mg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,262 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite cd2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite cd2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,267 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite zn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite zn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:08,269 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite cobalt2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite cobalt2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.core.model:Ignoring reaction 'EX_ac_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_adn_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_arab_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_asn_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_btn_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_ca2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_cd2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_cl_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_co2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_cobalt2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_cu2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_cys_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_fe2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_fe3_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_for_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_fru_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_gal_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_glc_D_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_glu_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_gly_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_glyb_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_h2o_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_h_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_hg2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_indole_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_k_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_lac_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_lcts_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_leu_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_lys_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_malt_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_malttr_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_man_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_met_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_mg2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_mn2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_na1_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_nac_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_nh4_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_o2_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_orn_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_pb_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_phe_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_pi_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_pro_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_ptrc_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_pydx_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_ser_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_so4_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_spmd_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_sucr_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_thr_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_thymd_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_trp_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_ura_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_urea_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_val_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_xan_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_zn2_medium' since it already exists.
# 2024-12-04 18:43:21,118 - pycomo - INFO - Note: no products in the objective function, adding biomass to it.
# INFO:pycomo:Note: no products in the objective function, adding biomass to it.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# 2024-12-04 18:43:26,315 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite q8. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite q8. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,319 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite chtbs. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite chtbs. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,322 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite glyglu. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite glyglu. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,324 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite _2ddglcn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite _2ddglcn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,327 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite glycys. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite glycys. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,330 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite cu2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite cu2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,332 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite glytyr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite glytyr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,335 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite cobalt2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite cobalt2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,338 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite alagln. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite alagln. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,341 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite mn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite mn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,343 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite alaglu. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite alaglu. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,346 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite alathr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite alathr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,349 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite zn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite zn2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,352 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite alagly. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite alagly. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,354 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite mantr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite mantr. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,357 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite glygln. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite glygln. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,360 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite gbbtn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite gbbtn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,363 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite pb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite pb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,365 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite glyasp. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite glyasp. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,368 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite metsox_S_L. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite metsox_S_L. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,371 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite arsenb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite arsenb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,374 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite ctbt. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite ctbt. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,376 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite met_D. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite met_D. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,379 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite alaleu. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite alaleu. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,381 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite mg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite mg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,384 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite strch1. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite strch1. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,386 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite alaasp. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite alaasp. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,389 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite glyasn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite glyasn. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,391 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite stys. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite stys. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,394 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite hg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite hg2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,396 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite sheme. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite sheme. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,399 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite cellb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite cellb. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,401 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite metsox_R_L. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite metsox_R_L. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,404 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite actn_R. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite actn_R. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,406 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite glymet. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite glymet. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,408 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite strch2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite strch2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# 2024-12-04 18:43:26,411 - pycomo - WARNING - WARNING: no annotation overlap found for matching metabolite cd2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:pycomo:WARNING: no annotation overlap found for matching metabolite cd2. Please make sure that the metabolite with this ID is indeed representing the same substance in all models!
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.core.model:Ignoring reaction 'EX__2ddglcn_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX__2obut_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_ac_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_acald_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_acgam_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_actn_R_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_ala_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_alaasp_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_alagln_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_alaglu_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_alagly_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_alahis_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_alaleu_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_alathr_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_arab_L_medium' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'EX_

# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# WARNING:cobra.medium.boundary_types:Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# 2024-12-04 18:45:00,523 - pycomo - WARNING - WARNING: Not all reactions in the model are mass and charge balanced. To check which reactions are imbalanced, please run the get_unbalanced_reactions method of this CommunityModel object
# WARNING:pycomo:WARNING: Not all reactions in the model are mass and charge balanced. To check which reactions are imbalanced, please run the get_unbalanced_reactions method of this CommunityModel object
# 2024-12-04 18:45:00,527 - pycomo - INFO - Generated community model.
# INFO:pycomo:Generated community model.
# <Model Representative_Gut_Microbiome at 0x79ced1bb5540>

# %% [markdown]
# The community model object has two utility methods to display information on the model.
#
# 1) Summary - behaves the same as the summary method of COBRApy, displaying the the solution of FBA and its exchange metabolites

# %%
com_model_obj.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 1.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>arg_L_medium</td>
#       <td>EX_arg_L_medium</td>
#       <td>0.2883</td>
#       <td>6</td>
#       <td>0.93%</td>
#     </tr>
#     <tr>
#       <td>asn_L_medium</td>
#       <td>EX_asn_L_medium</td>
#       <td>0.2347</td>
#       <td>4</td>
#       <td>0.50%</td>
#     </tr>
#     <tr>
#       <td>asp_L_medium</td>
#       <td>EX_asp_L_medium</td>
#       <td>19.77</td>
#       <td>4</td>
#       <td>42.48%</td>
#     </tr>
#     <tr>
#       <td>ca2_medium</td>
#       <td>EX_ca2_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cgly_medium</td>
#       <td>EX_cgly_medium</td>
#       <td>0.1046</td>
#       <td>5</td>
#       <td>0.28%</td>
#     </tr>
#     <tr>
#       <td>cl_medium</td>
#       <td>EX_cl_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_medium</td>
#       <td>EX_cobalt2_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_medium</td>
#       <td>EX_cu2_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_medium</td>
#       <td>EX_fe2_medium</td>
#       <td>0.01562</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fru_medium</td>
#       <td>EX_fru_medium</td>
#       <td>7.327</td>
#       <td>6</td>
#       <td>23.62%</td>
#     </tr>
#     <tr>
#       <td>gln_L_medium</td>
#       <td>EX_gln_L_medium</td>
#       <td>1.533</td>
#       <td>5</td>
#       <td>4.12%</td>
#     </tr>
#     <tr>
#       <td>glyleu_medium</td>
#       <td>EX_glyleu_medium</td>
#       <td>0.4387</td>
#       <td>8</td>
#       <td>1.89%</td>
#     </tr>
#     <tr>
#       <td>glymet_medium</td>
#       <td>EX_glymet_medium</td>
#       <td>0.05254</td>
#       <td>7</td>
#       <td>0.20%</td>
#     </tr>
#     <tr>
#       <td>his_L_medium</td>
#       <td>EX_his_L_medium</td>
#       <td>0.09262</td>
#       <td>6</td>
#       <td>0.30%</td>
#     </tr>
#     <tr>
#       <td>ile_L_medium</td>
#       <td>EX_ile_L_medium</td>
#       <td>0.2826</td>
#       <td>6</td>
#       <td>0.91%</td>
#     </tr>
#     <tr>
#       <td>k_medium</td>
#       <td>EX_k_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>lys_L_medium</td>
#       <td>EX_lys_L_medium</td>
#       <td>0.3336</td>
#       <td>6</td>
#       <td>1.08%</td>
#     </tr>
#     <tr>
#       <td>metsox_S_L_medium</td>
#       <td>EX_metsox_S_L_medium</td>
#       <td>0.1046</td>
#       <td>5</td>
#       <td>0.28%</td>
#     </tr>
#     <tr>
#       <td>mg2_medium</td>
#       <td>EX_mg2_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_medium</td>
#       <td>EX_mn2_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nmn_medium</td>
#       <td>EX_nmn_medium</td>
#       <td>0.9444</td>
#       <td>11</td>
#       <td>5.58%</td>
#     </tr>
#     <tr>
#       <td>o2_medium</td>
#       <td>EX_o2_medium</td>
#       <td>15.6</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>phe_L_medium</td>
#       <td>EX_phe_L_medium</td>
#       <td>0.1806</td>
#       <td>9</td>
#       <td>0.87%</td>
#     </tr>
#     <tr>
#       <td>pi_medium</td>
#       <td>EX_pi_medium</td>
#       <td>0.2197</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pnto_R_medium</td>
#       <td>EX_pnto_R_medium</td>
#       <td>0.01562</td>
#       <td>9</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>pydx_medium</td>
#       <td>EX_pydx_medium</td>
#       <td>0.007809</td>
#       <td>8</td>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <td>ribflv_medium</td>
#       <td>EX_ribflv_medium</td>
#       <td>0.01562</td>
#       <td>17</td>
#       <td>0.14%</td>
#     </tr>
#     <tr>
#       <td>ser_L_medium</td>
#       <td>EX_ser_L_medium</td>
#       <td>0.2097</td>
#       <td>3</td>
#       <td>0.34%</td>
#     </tr>
#     <tr>
#       <td>so4_medium</td>
#       <td>EX_so4_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>sucr_medium</td>
#       <td>EX_sucr_medium</td>
#       <td>1.296</td>
#       <td>12</td>
#       <td>8.35%</td>
#     </tr>
#     <tr>
#       <td>thr_L_medium</td>
#       <td>EX_thr_L_medium</td>
#       <td>0.2467</td>
#       <td>4</td>
#       <td>0.53%</td>
#     </tr>
#     <tr>
#       <td>trp_L_medium</td>
#       <td>EX_trp_L_medium</td>
#       <td>0.05516</td>
#       <td>11</td>
#       <td>0.33%</td>
#     </tr>
#     <tr>
#       <td>tyr_L_medium</td>
#       <td>EX_tyr_L_medium</td>
#       <td>0.1343</td>
#       <td>9</td>
#       <td>0.65%</td>
#     </tr>
#     <tr>
#       <td>ura_medium</td>
#       <td>EX_ura_medium</td>
#       <td>1.154</td>
#       <td>4</td>
#       <td>2.48%</td>
#     </tr>
#     <tr>
#       <td>val_L_medium</td>
#       <td>EX_val_L_medium</td>
#       <td>0.4116</td>
#       <td>5</td>
#       <td>1.11%</td>
#     </tr>
#     <tr>
#       <td>xan_medium</td>
#       <td>EX_xan_medium</td>
#       <td>1.092</td>
#       <td>5</td>
#       <td>2.93%</td>
#     </tr>
#     <tr>
#       <td>zn2_medium</td>
#       <td>EX_zn2_medium</td>
#       <td>0.007809</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ac_medium</td>
#       <td>EX_ac_medium</td>
#       <td>-23.35</td>
#       <td>2</td>
#       <td>32.07%</td>
#     </tr>
#     <tr>
#       <td>adn_medium</td>
#       <td>EX_adn_medium</td>
#       <td>-0.6514</td>
#       <td>10</td>
#       <td>4.47%</td>
#     </tr>
#     <tr>
#       <td>ala_L_medium</td>
#       <td>EX_ala_L_medium</td>
#       <td>-1.84</td>
#       <td>3</td>
#       <td>3.79%</td>
#     </tr>
#     <tr>
#       <td>co2_medium</td>
#       <td>EX_co2_medium</td>
#       <td>-36.16</td>
#       <td>1</td>
#       <td>24.84%</td>
#     </tr>
#     <tr>
#       <td>for_medium</td>
#       <td>EX_for_medium</td>
#       <td>-10.99</td>
#       <td>1</td>
#       <td>7.55%</td>
#     </tr>
#     <tr>
#       <td>glu_L_medium</td>
#       <td>EX_glu_L_medium</td>
#       <td>-0.7135</td>
#       <td>5</td>
#       <td>2.45%</td>
#     </tr>
#     <tr>
#       <td>glyc_medium</td>
#       <td>EX_glyc_medium</td>
#       <td>-7.327</td>
#       <td>3</td>
#       <td>15.10%</td>
#     </tr>
#     <tr>
#       <td>nac_medium</td>
#       <td>EX_nac_medium</td>
#       <td>-0.9288</td>
#       <td>6</td>
#       <td>3.83%</td>
#     </tr>
#     <tr>
#       <td>nh4_medium</td>
#       <td>EX_nh4_medium</td>
#       <td>-16.65</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>thymd_medium</td>
#       <td>EX_thymd_medium</td>
#       <td>-0.8606</td>
#       <td>10</td>
#       <td>5.91%</td>
#     </tr>
#     <tr>
#       <td>cpd11416_medium</td>
#       <td>community_biomass</td>
#       <td>-1</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2) Report
#
# The report function displays information on the model structure: the number of metabolites, reactions, genes, etc., but also quality control measures on mass and charge balance and internal loops.

# %%
com_model_obj.report()
# Out:
# 2024-12-04 18:56:51,714 - pycomo - INFO - Note: The model has more than 5000 reactions. Calculation of loops is skipped, as this would take some time. If needed, please run manually via .get_loops()
# INFO:pycomo:Note: The model has more than 5000 reactions. Calculation of loops is skipped, as this would take some time. If needed, please run manually via .get_loops()
# Name: Representative_Gut_Microbiome
# ------------------
# Model overview
# Model structure: fixed growth rate
# # Metabolites: 19598
# # Constraint (f-) Metabolites: 12020
# # Model Metabolites: 7578
# # Reactions: 20696
# # Constraint (f-) Reactions: 12019
# # Model Reactions: 8677
# # Genes: 4971
# # Members: 7
# Members:
# 	Streptococcus_anginosus_1_2_62CV
# 	Bacteroides_fragilis_NCTC_9343
# 	Streptococcus_thoraltensis_DSM_12221
# 	Shigella_sonnei_Ss046
# 	Sulfolobus_solfataricus_P2
# 	Porphyromonas_uenonis_60_3
# 	Clostridium_bartlettii_DSM_16795
# Objective in direction max:
# 	1.0*community_biomass - 1.0*community_biomass_reverse_44dc1
# ------------------
# Model quality
# # Reactions unbalanced: 87
# # Reactions able to carry flux without a medium: NaN
# {'community_name': 'Representative_Gut_Microbiome',
#  'model_structure': 'fixed growth rate',
#  'num_metabolites': 19598,
#  'num_f_metabolites': 12020,
#  'num_model_metabolites': 7578,
#  'num_reactions': 20696,
#  'num_f_reactions': 12019,
#  'num_model_reactions': 8677,
#  'num_genes': 4971,
#  'member_names': ['Streptococcus_anginosus_1_2_62CV',
#   'Bacteroides_fragilis_NCTC_9343',
#   'Streptococcus_thoraltensis_DSM_12221',
#   'Shigella_sonnei_Ss046',
#   'Sulfolobus_solfataricus_P2',
#   'Porphyromonas_uenonis_60_3',
#   'Clostridium_bartlettii_DSM_16795'],
#  'num_members': 7,
#  'objective_expression': 1.0*community_biomass - 1.0*community_biomass_reverse_44dc1,
#  'objective_direction': 'max',
#  'unbalanced_reactions': {<Reaction Streptococcus_anginosus_1_2_62CV_DM_2HYMEPH_Streptococcus_anginosus_1_2_62CV_c at 0x79cec5373640>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_DM_HQN_Streptococcus_anginosus_1_2_62CV_c at 0x79cec5373700>: {'C': -6.0,
#    'H': -6.0,
#    'O': -2.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_DM_dhptd_Streptococcus_anginosus_1_2_62CV_c at 0x79cec5372ec0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_EX_biomass_e_Streptococcus_anginosus_1_2_62CV_c at 0x79cec5390e80>: {'X': -1.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_GLCP3_Streptococcus_anginosus_1_2_62CV_c at 0x79cec53d46d0>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_GLCS3_Streptococcus_anginosus_1_2_62CV_c at 0x79cec53d4790>: {'charge': -1.0,
#    'H': -1.0,
#    'X': -1.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_dreplication_Streptococcus_anginosus_1_2_62CV_c at 0x79cec52a1660>: {'X': 1.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_pbiosynthesis_Streptococcus_anginosus_1_2_62CV_c at 0x79cec52a1690>: {'X': 1.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_rtranscription_Streptococcus_anginosus_1_2_62CV_c at 0x79cec52a3eb0>: {'X': 1.0},
#   <Reaction Streptococcus_anginosus_1_2_62CV_biomass528 at 0x79cec52a3f70>: {'charge': 1.107429799999978,
#    'C': -40.53837440000002,
#    'H': -62.38455799999992,
#    'N': -11.819075200000025,
#    'O': -15.827772600000213,
#    'P': -1.1641147999999983,
#    'S': -0.2695576,
#    'X': -2.0,
#    'Ca': -0.0078094,
#    'Cl': -0.0078094,
#    'Co': -0.0078094,
#    'Cu': -0.0078094,
#    'Fe': -0.0156188,
#    'K': -0.0078094,
#    'Mg': -0.0078094,
#    'Mn': -0.0078094,
#    'Zn': -0.0078094},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DHNAOPT_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2665d20>: {'charge': 2.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_4HBA_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2ade320>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_5DRIB_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2ade9e0>: {'C': -5.0,
#    'H': -10.0,
#    'O': -4.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_5MTR_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2b11000>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_AMOB_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2ade950>: {'C': -15.0,
#    'H': -19.0,
#    'N': -5.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_btn_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2adeef0>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -15.0,
#    'N': -2.0,
#    'O': -3.0,
#    'S': -1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_Bacteroides_fragilis_NCTC_9343_clpn180_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2adfee0>: {'charge': 2.0,
#    'C': -81.0,
#    'H': -156.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_Bacteroides_fragilis_NCTC_9343_clpnai17_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2adfca0>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_Bacteroides_fragilis_NCTC_9343_clpni17_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2adf3a0>: {'charge': 2.0,
#    'C': -77.0,
#    'H': -148.0,
#    'O': -17.0,
#    'P': -2.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_dad_5_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2adf520>: {'C': -10.0,
#    'H': -13.0,
#    'N': -5.0,
#    'O': -3.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_DM_kdo2lipid4L_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2b136d0>: {'charge': 6.0,
#    'C': -96.0,
#    'H': -170.0,
#    'N': -2.0,
#    'O': -38.0,
#    'P': -2.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_EX_biomass_e_Bacteroides_fragilis_NCTC_9343_c at 0x79cec29488b0>: {'X': -1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_GLCP3_Bacteroides_fragilis_NCTC_9343_c at 0x79cec27a62f0>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_SHCHCC2_Bacteroides_fragilis_NCTC_9343_c at 0x79cec268ee90>: {'charge': -2.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_dreplication_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2adf0d0>: {'X': 1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_pbiosynthesis_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2adfb50>: {'X': 1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_rtranscription_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2b133d0>: {'X': 1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_sink_gthrd_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2b10340>: {'charge': 1.0,
#    'C': -10.0,
#    'H': -16.0,
#    'N': -3.0,
#    'O': -6.0,
#    'S': -1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_sink_s_Bacteroides_fragilis_NCTC_9343_c at 0x79cec2b12ec0>: {'S': -1.0},
#   <Reaction Bacteroides_fragilis_NCTC_9343_biomass345 at 0x79cec196d360>: {'charge': 0.855651000000081,
#    'C': -39.34615600000004,
#    'H': -62.78396450000044,
#    'N': -8.570865499999943,
#    'O': -14.310895000000304,
#    'P': -0.8120795000000108,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_DM_2HYMEPH_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf5d8d90>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_DM_5MTR_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf59f430>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_DM_HQN_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf59c5b0>: {'C': -6.0,
#    'H': -6.0,
#    'O': -2.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_DM_dhptd_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf5d9330>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_DM_hcys_L_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf5d94e0>: {'C': -4.0,
#    'H': -9.0,
#    'N': -1.0,
#    'O': -2.0,
#    'S': -1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_EX_biomass_e_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf59d9c0>: {'X': -1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_TECA4S_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf548e80>: {'charge': -30.0,
#    'C': -420.0,
#    'H': -752.0,
#    'N': -30.0,
#    'O': -391.0,
#    'P': -30.0,
#    'X': 1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_TECAAE_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf548a00>: {'C': -286.0,
#    'H': -477.0,
#    'N': -47.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_TECAGE_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf549360>: {'charge': 45.0,
#    'C': -421.0,
#    'H': -747.0,
#    'N': -2.0,
#    'O': -463.0,
#    'P': -46.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_TECAUE_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf549960>: {'charge': 45.0,
#    'C': -151.0,
#    'H': -297.0,
#    'N': -2.0,
#    'O': -238.0,
#    'P': -46.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_dreplication_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf56b310>: {'X': 1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_pbiosynthesis_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf56b9d0>: {'X': 1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_rtranscription_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf59c5e0>: {'X': 1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_sink_PGPm1_Streptococcus_thoraltensis_DSM_12221_c at 0x79cebf59c1c0>: {'X': -1.0},
#   <Reaction Streptococcus_thoraltensis_DSM_12221_biomass109 at 0x79cebfd0a320>: {'charge': -81.86881919999985,
#    'C': -35.036571200000004,
#    'H': 26.148495400000314,
#    'N': -7.352876799999987,
#    'O': 68.97888829999954,
#    'P': -0.9387277000000417,
#    'S': -0.21809219999999996,
#    'X': -2.0018063,
#    'Co': -0.0079397,
#    'Ca': -0.0079397,
#    'Cl': -0.0079397,
#    'Cu': -0.0079397,
#    'Fe': -0.0317588,
#    'K': -0.0079397,
#    'Mg': -0.0079397,
#    'Mn': -0.0079397,
#    'Zn': -0.0079397},
#   <Reaction Shigella_sonnei_Ss046_CBL2D_Shigella_sonnei_Ss046_c at 0x79cebb02f070>: {'H': 8.0},
#   <Reaction Shigella_sonnei_Ss046_DHNAOT_Shigella_sonnei_Ss046_c at 0x79cebb1d2e90>: {'charge': 2.0},
#   <Reaction Shigella_sonnei_Ss046_DM_5DRIB_Shigella_sonnei_Ss046_c at 0x79cebb68f8b0>: {'C': -5.0,
#    'H': -10.0,
#    'O': -4.0},
#   <Reaction Shigella_sonnei_Ss046_DM_5MTR_Shigella_sonnei_Ss046_c at 0x79cebb68fee0>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Shigella_sonnei_Ss046_DM_dhptd_Shigella_sonnei_Ss046_c at 0x79cebb68f1f0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Shigella_sonnei_Ss046_DM_hcys_L_Shigella_sonnei_Ss046_c at 0x79cebb6b8820>: {'C': -4.0,
#    'H': -9.0,
#    'N': -1.0,
#    'O': -2.0,
#    'S': -1.0},
#   <Reaction Shigella_sonnei_Ss046_EX_biomass_e_Shigella_sonnei_Ss046_c at 0x79cebb68fb80>: {'X': -1.0},
#   <Reaction Shigella_sonnei_Ss046_dreplication_Shigella_sonnei_Ss046_c at 0x79cebb6f49d0>: {'X': 1.0},
#   <Reaction Shigella_sonnei_Ss046_pbiosynthesis_Shigella_sonnei_Ss046_c at 0x79cebb6f57b0>: {'X': 1.0},
#   <Reaction Shigella_sonnei_Ss046_rtranscription_Shigella_sonnei_Ss046_c at 0x79cebb6bb280>: {'X': 1.0},
#   <Reaction Shigella_sonnei_Ss046_biomass355 at 0x79cebc0a6680>: {'charge': 0.8556430000000443,
#    'C': -39.34589100000009,
#    'H': -62.783694500000436,
#    'N': -8.571103499999968,
#    'O': -14.31086900000037,
#    'P': -0.812073500000026,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Sulfolobus_solfataricus_P2_DM_4HBA_Sulfolobus_solfataricus_P2_c at 0x79ceb7cbb010>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Sulfolobus_solfataricus_P2_DM_dhptd_Sulfolobus_solfataricus_P2_c at 0x79ceb7cbaef0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Sulfolobus_solfataricus_P2_DM_hcys_L_Sulfolobus_solfataricus_P2_c at 0x79ceb7cbb490>: {'C': -4.0,
#    'H': -9.0,
#    'N': -1.0,
#    'O': -2.0,
#    'S': -1.0},
#   <Reaction Sulfolobus_solfataricus_P2_EX_biomass_e_Sulfolobus_solfataricus_P2_c at 0x79ceb7cba8c0>: {'X': -1.0},
#   <Reaction Sulfolobus_solfataricus_P2_dreplication_Sulfolobus_solfataricus_P2_c at 0x79ceb7cbbee0>: {'X': 1.0},
#   <Reaction Sulfolobus_solfataricus_P2_pbiosynthesis_Sulfolobus_solfataricus_P2_c at 0x79ceb7cf4400>: {'X': 1.0},
#   <Reaction Sulfolobus_solfataricus_P2_rtranscription_Sulfolobus_solfataricus_P2_c at 0x79ceb7cbbfa0>: {'X': 1.0},
#   <Reaction Sulfolobus_solfataricus_P2_biomass249 at 0x79ceb81f96c0>: {'charge': 0.8556530000000571,
#    'C': -39.350789000000056,
#    'H': -62.788607500000396,
#    'N': -8.566340499999942,
#    'O': -14.310929000000382,
#    'P': -0.8120835000000071,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Porphyromonas_uenonis_60_3_DHNAOT_Porphyromonas_uenonis_60_3_c at 0x79ceb50735b0>: {'charge': 2.0},
#   <Reaction Porphyromonas_uenonis_60_3_DM_5MTR_Porphyromonas_uenonis_60_3_c at 0x79ceb5239420>: {'C': -6.0,
#    'H': -12.0,
#    'O': -4.0,
#    'S': -1.0},
#   <Reaction Porphyromonas_uenonis_60_3_DM_dhptd_Porphyromonas_uenonis_60_3_c at 0x79ceb5238460>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Porphyromonas_uenonis_60_3_DM_hcys_L_Porphyromonas_uenonis_60_3_c at 0x79ceb523a500>: {'C': -4.0,
#    'H': -9.0,
#    'N': -1.0,
#    'O': -2.0,
#    'S': -1.0},
#   <Reaction Porphyromonas_uenonis_60_3_EX_biomass_e_Porphyromonas_uenonis_60_3_c at 0x79ceb52648b0>: {'X': -1.0},
#   <Reaction Porphyromonas_uenonis_60_3_SHCHCC2_Porphyromonas_uenonis_60_3_c at 0x79ceb50a5960>: {'charge': -2.0},
#   <Reaction Porphyromonas_uenonis_60_3_dreplication_Porphyromonas_uenonis_60_3_c at 0x79ceb5239210>: {'X': 1.0},
#   <Reaction Porphyromonas_uenonis_60_3_pbiosynthesis_Porphyromonas_uenonis_60_3_c at 0x79ceb523a050>: {'X': 1.0},
#   <Reaction Porphyromonas_uenonis_60_3_rtranscription_Porphyromonas_uenonis_60_3_c at 0x79ceb523bf10>: {'X': 1.0},
#   <Reaction Porphyromonas_uenonis_60_3_biomass368 at 0x79ceb5073f40>: {'charge': 0.8556350000000645,
#    'C': -39.345330000000025,
#    'H': -62.78312850000039,
#    'N': -8.571637499999927,
#    'O': -14.310843000000322,
#    'P': -0.8120675000000127,
#    'S': -0.222525,
#    'X': -2.0,
#    'Co': -0.0030965,
#    'Ca': -0.0030965,
#    'Cl': -0.0030965,
#    'Cu': -0.0030965,
#    'Fe': -0.012386,
#    'K': -0.0030965,
#    'Mg': -0.0030965,
#    'Mn': -0.0030965,
#    'Zn': -0.0030965},
#   <Reaction Clostridium_bartlettii_DSM_16795_DM_4HBA_Clostridium_bartlettii_DSM_16795_c at 0x79ceb2755c90>: {'C': -7.0,
#    'H': -8.0,
#    'O': -2.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_DM_HQN_Clostridium_bartlettii_DSM_16795_c at 0x79ceb2754670>: {'C': -6.0,
#    'H': -6.0,
#    'O': -2.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_DM_dhptd_Clostridium_bartlettii_DSM_16795_c at 0x79ceb28eadd0>: {'C': -5.0,
#    'H': -8.0,
#    'O': -4.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_EX_biomass_e_Clostridium_bartlettii_DSM_16795_c at 0x79ceb291beb0>: {'X': -1.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_GLCP3_Clostridium_bartlettii_DSM_16795_c at 0x79ceb2566260>: {'charge': -1.0,
#    'H': -1.0,
#    'X': 1.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_GLCS3_Clostridium_bartlettii_DSM_16795_c at 0x79ceb2566860>: {'charge': -1.0,
#    'H': -1.0,
#    'X': -1.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_SHCHCC2_Clostridium_bartlettii_DSM_16795_c at 0x79ceb2461930>: {'charge': -2.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_TECA4S_Clostridium_bartlettii_DSM_16795_c at 0x79ceb28c6d10>: {'charge': -30.0,
#    'C': -420.0,
#    'H': -752.0,
#    'N': -30.0,
#    'O': -391.0,
#    'P': -30.0,
#    'X': 1.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_dreplication_Clostridium_bartlettii_DSM_16795_c at 0x79ceb28ebc10>: {'X': 1.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_pbiosynthesis_Clostridium_bartlettii_DSM_16795_c at 0x79ceb28ebb50>: {'X': 1.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_rtranscription_Clostridium_bartlettii_DSM_16795_c at 0x79ceb2919f60>: {'X': 1.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_sink_dmbzid_Clostridium_bartlettii_DSM_16795_c at 0x79ceb2918f70>: {'C': -9.0,
#    'H': -10.0,
#    'N': -2.0},
#   <Reaction Clostridium_bartlettii_DSM_16795_biomass524 at 0x79ceb2ed3490>: {'charge': 0.3815901999999309,
#    'C': -30.380721800000003,
#    'H': -46.7338868000001,
#    'N': -8.483003999999994,
#    'O': -11.269859399999739,
#    'P': -0.6922194000000467,
#    'S': -0.27819900000000003,
#    'X': -2.016391,
#    'Ca': -0.020024,
#    'Cl': -0.020024,
#    'Co': -0.020024,
#    'Cu': -0.020024,
#    'Fe': -0.040048,
#    'K': -0.020024,
#    'Mg': -0.020024,
#    'Mn': -0.020024,
#    'Zn': -0.020024}},
#  'num_unbalanced_reactions': 87,
#  'reactions_in_loops': 'NaN',
#  'num_loop_reactions': 'NaN'}

# %% [markdown]
# <p align="justify">By default the community model object will have the structure of fixe growth rate. This means, the fractions of the community member abundance is allowed to vary during simulations, but the individual and community growth rate is set to a fixed value (default: 1.0). To visualize the potential cross-feeding relationships between orhanisms, a fixed equal abundance community was used.</p>

# %%
com_model_obj.convert_to_fixed_abundance()
abundance_dict = com_model_obj.generate_equal_abundance_dict()
com_model_obj.apply_fixed_abundance(abundance_dict)
com_model_obj.summary()
# Out:
# <h3>Objective</h3><p>1.0 community_biomass = 57.16413569458435</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>_26dap_M_medium</td>
#       <td>EX__26dap_M_medium</td>
#       <td>0.7613</td>
#       <td>7</td>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <td
td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <td>metsox_S_L_medium</td>
#       <td>EX_metsox_S_L_medium</td>
#       <td>1.283</td>
#       <td>5</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>mg2_medium</td>
#       <td>EX_mg2_medium</td>
#       <td>0.3933</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_medium</td>
#       <td>EX_mn2_medium</td>
#       <td>0.3933</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>

# %%
com_model_obj.model.optimize()
# Out:
# <Solution 57.164 at 0x79ceba106140>

# %%
abundance_dict # Investigating the abundances of each organism
# Out:
# {'Streptococcus_anginosus_1_2_62CV': 0.14285714285714285,
#  'Bacteroides_fragilis_NCTC_9343': 0.14285714285714285,
#  'Streptococcus_thoraltensis_DSM_12221': 0.14285714285714285,
#  'Shigella_sonnei_Ss046': 0.14285714285714285,
#  'Sulfolobus_solfataricus_P2': 0.14285714285714285,
#  'Porphyromonas_uenonis_60_3': 0.14285714285714285,
#  'Clostridium_bartlettii_DSM_16795': 0.14285714285714285}

# %%
com_model_obj.save("/content/drive/My Drive/Rotation 1/Representative_Gut_Microbiome.xml")

# %%
com_model_obj.fba_solution_flux_vector('/content/drive/My Drive/Rotation 1/FBA_flux_file')
# Out:
# 2024-12-04 19:37:04,162 - pycomo - INFO - Saving flux vector to /content/drive/My Drive/Rotation 1/FBA_flux_file
# INFO:pycomo:Saving flux vector to /content/drive/My Drive/Rotation 1/FBA_flux_file
#                                                                                           reaction_id  \
# Streptococcus_anginosus_1_2_62CV__2HMCOXT_Strep...  Streptococcus_anginosus_1_2_62CV__2HMCOXT_Stre...
# Streptococcus_anginosus_1_2_62CV__2MBCOATA_Stre...  Streptococcus_anginosus_1_2_62CV__2MBCOATA_Str...
# Streptococcus_anginosus_1_2_62CV__3HAD100_Strep...  Streptococcus_anginosus_1_2_62CV__3HAD100_Stre...
# Streptococcus_anginosus_1_2_62CV__3HAD10M11_Str...  Streptococcus_anginosus_1_2_62CV__3HAD10M11_St...
# Streptococcus_anginosus_1_2_62CV__3HAD10M12_Str...  Streptococcus_anginosus_1_2_62CV__3HAD10M12_St...
# ...                                                                                               ...
# SK_Clostridium_bartlettii_DSM_16795_TF_no3_Clos...  SK_Clostridium_bartlettii_DSM_16795_TF_no3_Clo...
# SK_Clostridium_bartlettii_DSM_16795_to_communit...  SK_Clostridium_bartlettii_DSM_16795_to_communi...
# f_final                                                                                       f_final
# abundance_reaction                                                                 abundance_reaction
# community_biomass                                                                   community_biomass
#
#                                                          flux
# Streptococcus_anginosus_1_2_62CV__2HMCOXT_Strep...   0.000000
# Streptococcus_anginosus_1_2_62CV__2MBCOATA_Stre...   0.000000
# Streptococcus_anginosus_1_2_62CV__3HAD100_Strep...   0.000000
# Streptococcus_anginosus_1_2_62CV__3HAD10M11_Str...   0.000000
# Streptococcus_anginosus_1_2_62CV__3HAD10M12_Str...   0.000000
# ...                                                       ...
# SK_Clostridium_bartlettii_DSM_16795_TF_no3_Clos...   1.428571
# SK_Clostridium_bartlettii_DSM_16795_to_communit...   1.346908
# f_final                                              1.000000
# abundance_reaction                                  57.164136
# community_biomass                                   57.164136
#
# [20696 rows x 2 columns]
