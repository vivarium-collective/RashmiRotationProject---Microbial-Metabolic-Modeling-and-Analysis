# %%
import os
import cobra
from cobra.io import read_sbml_model
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
def import_models(file_path, extension='.xml'):
    files = [file for file in os.listdir(file_path) if file.endswith(extension)]
    models={}
    for x in files:
        split_name = x.split('.')
        file_name = split_name[0]
        models[file_name] = file_path + x
        
    return models

# %%
file_path = 'C:/Users/User/Documents/GitHub/10 AGORA models/'
models = import_models(file_path)

# %%
def FBA_solver(models, reaction = 'EX_glc_D(e)'):
    model_results = [[] for i in range(len(models.keys()))]
    x = 0
    for y in models.keys():
        model = read_sbml_model(models[y])
        solution = model.optimize()
        while x < 10:
            model_results[x].append(y)
            model_results[x].append(solution.objective_value)
            model_results[x].append(solution.fluxes[reaction])
            break
        x += 1
        
    df = pd.DataFrame(model_results, columns=['Model Name', 'Growth', 'Glucose Flux'], index=[i for i in range(1, len(model_results)+1)])
    return df

FBA_solver(models)
# Out:
#                                            Model Name      Growth  \
# 1                    Abiotrophia_defectiva_ATCC_49176   65.662169
# 2                       Actinomyces_georgiae_DSM_6843   50.144125
# 3                         Bacillus_altitudinis_41KF2b   72.901606
# 4   Bifidobacterium_thermacidophilum_subsp_thermac...   79.944926
# 5                     Bradyrhizobium_japonicum_USDA_6   83.867455
# 6                  Clostridium_botulinum_F_str_230613   83.714319
# 7                               Hafnia_alvei_BIDMC_31  159.051383
# 8                        Klebsiella_oxytoca_KCTC_1686  157.596633
# 9                        Paenibacillus_graminis_C4D1M  179.263560
# 10                   Raoultella_planticola_ATCC_33531  156.565919
#
#     Glucose Flux
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# 5       0.000000
# 6       0.000000
# 7       0.000000
# 8     -19.708247
# 9       0.000000
# 10      0.000000

# %%
import pandas as pd

def FBA_solver(models, reaction='EX_glc_D(e)'):
    model_results = []
    
    for i, model_name in enumerate(models.keys()):
        if i >= 10:  # Limit to 10 models
            break
        
        model = read_sbml_model(models[model_name])
        solution = model.optimize()
        
        if solution.status == 'optimal':  # Check if the solution is optimal
            model_results.append([
                model_name,
                solution.objective_value,
                solution.fluxes.get(reaction, 0)  # Use .get() to avoid KeyError
            ])
        else:
            model_results.append([
                model_name,
                None,  # No growth value if not optimal
                None   # No glucose flux if not optimal
            ])
    
    df = pd.DataFrame(model_results, columns=['Model Name', 'Growth', 'Glucose Flux'])
    return df

#Example usage:
df = FBA_solver(models)
df
# Out:
#                                           Model Name      Growth  Glucose Flux
# 0                   Abiotrophia_defectiva_ATCC_49176   65.662169      0.000000
# 1                      Actinomyces_georgiae_DSM_6843   50.144125      0.000000
# 2                        Bacillus_altitudinis_41KF2b   72.901606      0.000000
# 3  Bifidobacterium_thermacidophilum_subsp_thermac...   79.944926      0.000000
# 4                    Bradyrhizobium_japonicum_USDA_6   83.867455      0.000000
# 5                 Clostridium_botulinum_F_str_230613   83.714319      0.000000
# 6                              Hafnia_alvei_BIDMC_31  159.051383      0.000000
# 7                       Klebsiella_oxytoca_KCTC_1686  157.596633    -19.708247
# 8                       Paenibacillus_graminis_C4D1M  179.263560      0.000000
# 9                   Raoultella_planticola_ATCC_33531  156.565919      0.000000

# %%
def get_exchange_reactions(models):
    model_name = []
    exchange_reactions = []
    exchange_fluxes = [[] for i in range (len(models.keys()))]
    i = 0
    for y in models.keys():
        model = read_sbml_model(models[y])
        model_name.append(y)
        new_exchange_reactions = [exr.id for exr in model.reactions if exr.id.startswith("EX_") and exr.id not in exchange_reactions]
        exchange_reactions.extend(new_exchange_reactions)
        
    for y in models.keys():
        model = read_sbml_model(models[y])        
        solution = model.optimize()
        for x in exchange_reactions:
            if x in model.reactions:
                flux_value = solution.fluxes.get(x)
                exchange_fluxes[i].append(flux_value)
            else:
                exchange_fluxes[i].append(None)
                              
        i += 1
            
    
    return model_name, exchange_reactions, exchange_fluxes
#     return len(exchange_fluxes[1])

# %%
model_name, exchange_reactions, exchange_fluxes = get_exchange_reactions(models)

#len(exchange_fluxes[0])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.DataFrame(exchange_fluxes, columns=[exchange_reactions], index=[model_name])
df
# Out:
#                                                      EX_4abut(e)     EX_ac(e)  \
# Abiotrophia_defectiva_ATCC_49176                    9.818949e+02  1000.000000
# Actinomyces_georgiae_DSM_6843                                NaN  1000.000000
# Bacillus_altitudinis_41KF2b                         2.149313e-12  1000.000000
# Bifidobacterium_thermacidophilum_subsp_thermaci...           NaN  1000.000000
# Bradyrhizobium_japonicum_USDA_6                              NaN  1000.000000
# Clostridium_botulinum_F_str_230613                           NaN  1000.000000
# Hafnia_alvei_BIDMC_31                               0.000000e+00     7.956068
# Klebsiella_oxytoca_KCTC_1686                                 NaN  1000.000000
# Paenibacillus_graminis_C4D1M                                 NaN  1000.000000
# Raoultella_planticola_ATCC_33531                             NaN  1000.000000
#
#                                                     EX_acald(e) EX_adocbl(e)  \
# ...

# %%
len(df)
# Out:
# 10

# %%
import seaborn as sns

plt.figure(figsize=(50, 20))
sns.heatmap(df, cmap='viridis', cbar=True)
plt.title('Heatmap of Exchange Reactions for Microbial Species', fontsize=20)
plt.xlabel('Exchange Reaction Fluxes', fontsize=20)
plt.ylabel('Species', fontsize=20)
plt.yticks(fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Identifying the number of PCA components that best capture 90 - 95% variance

# %%
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

X = df.values
species = df.index 

# If your columns are tuples, flatten them
df.columns = ['_'.join(map(str, col)) if isinstance(col, tuple) else str(col) for col in df.columns]

# Initialize SimpleImputer with constant strategy to replace missing fluxes with 0
imputer = SimpleImputer(strategy='constant', fill_value=0)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_imputed)

# Assuming X_transformed is your PCA-transformed data
pca = PCA()
pca.fit(df_imputed)

# Plotting the explained variance
plt.figure(figsize=(8, 5))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance vs. Number of Components')
plt.axhline(y=0.90, color='r', linestyle='--')  # Example for 90% variance
plt.axhline(y=0.95, color='g', linestyle='--')  # Example for 95% variance
plt.show()

# %%
# Plotting the Scree plot
plt.figure(figsize=(8, 5))
plt.plot(pca.explained_variance_, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot')
plt.show()

# %%
# Perform PCA to reduce dimensions to 6
pca = PCA(n_components=2)
X_r = pca.fit_transform(scaled_data)

# Create the scatter plot
plt.figure(figsize=(10, 8))
colors = plt.cm.get_cmap('tab10', len(species.unique()))  # Get a color map

# Plot each species using the unique species names directly
for i, name in enumerate(species.unique()):
    plt.scatter(X_r[species == name, 0], X_r[species == name, 1], color=colors(i), label=name)

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust this to move the legend
# Set axis limits to center (0, 0)
plt.xlim([-15, 20])  # Adjust these limits as necessary
plt.title('PCA of Dataset with Species as Index')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Show the plot
plt.show()

# %%
# Get the principal components
components = pca.components_  # Shape: (n_components, n_features)

# Get the explained variance
explained_variance = pca.explained_variance_ratio_

# Create a DataFrame to show loadings
loadings_df = pd.DataFrame(components.T, columns=[f'PC{i+1}' for i in range(components.shape[0])], index=df.columns)
print(loadings_df)
# Out:
#                              PC1           PC2
# EX_4abut(e)         2.291692e-02  4.473481e-02
# EX_ac(e)            3.830687e-02  5.438424e-02
# EX_acald(e)        -8.001717e-02  9.901145e-02
# EX_adocbl(e)       -5.692322e-17 -2.719767e-16
# EX_ala_L(e)        -1.387772e-01  6.823852e-03
# EX_alaasp(e)       -4.625351e-02  3.731109e-02
# EX_alagln(e)       -1.289513e-01 -2.293112e-02
# EX_alaglu(e)       -8.051092e-17 -1.560642e-16
# EX_alagly(e)       -2.833835e-17 -3.515396e-17
# EX_alahis(e)        1.055260e-01  1.412100e-01
# EX_alaleu(e)       -1.926442e-02 -8.844751e-02
# EX_alathr(e)       -3.900680e-02 -9.184423e-02
# EX_arab_L(e)       -0.000000e+00  0.000000e+00
# EX_arg_L(e)         1.069880e-01  2.891385e-02
# EX_arsenb(e)       -0.000000e+00  0.000000e+00
# EX_asn_L(e)         5.702924e-03  1.468153e-01
# EX_aso3(e)         -0.000000e+00  0.000000e+00
# EX_aso4(e)         -0.000000e+00  0.000000e+00
# EX_asp_L(e)         9.388851e-02 -9.610848e-02
# ...

# %%
loadings = pca.components_.T  # Transpose to get loadings per exchange reaction
reaction_ids = df.columns   # Exchange reaction IDs from the DataFrame

plt.figure(figsize=(40, 20))
bar_width = 0.6
plt.bar(reaction_ids, loadings[:, 0], width=bar_width,label='PC1')
plt.bar(reaction_ids, loadings[:, 1], width=bar_width,label='PC2')
plt.title('PCA Loadings: Contribution of Exchange Reactions to PCs')
plt.xlabel('Exchange Reactions')
plt.ylabel('Loadings')
plt.xticks(rotation=90,fontsize=8)# Rotate the x-axis labels to make them readable
plt.legend()
plt.tight_layout()  # Adjust layout to ensure everything fits
plt.show()

# %% [markdown]
# ### Determining the optimal number of clusters for K Means Clustering

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Initialize lists to store inertia and silhouette scores
inertia = []
silhouette_scores = []
k_range = range(2, 9)  # You can adjust this range as needed

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_r)
    inertia.append(kmeans.inertia_)  # Sum of squared distances to closest cluster center
    silhouette_scores.append(silhouette_score(X_r, kmeans.labels_))  # Silhouette score
    
# Elbow Method Plot
plt.figure(figsize=(10, 6))
plt.plot(k_range, inertia, marker='o')
plt.title('Elbow Method for Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.xticks(k_range)
plt.grid()
plt.show()

# %%
# Silhouette Score Plot
plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, marker='o')
plt.title('Silhouette Score for Different K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.xticks(k_range)
plt.grid()
plt.show()

# %%
from sklearn.cluster import KMeans

# Performing K-means clustering
n_clusters = 7  # Set the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
y_kmeans = kmeans.fit_predict(X_r)

# Step 2: Create the plot
plt.figure(figsize=(10, 8))
plt.scatter(X_r[:, 0], X_r[:, 1], c=y_kmeans, s=50, cmap='viridis')  # Clustered points
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, label='Centroids')

# Step 3: Add titles and labels
plt.title('K-means Clustering on PCA Results')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Set axis limits to center (0, 0)
plt.xlim([-15, 20])  # Adjust these limits as necessary
plt.legend()
plt.grid()
plt.show()

# %%
from matplotlib.patches import FancyArrowPatch
from adjustText import adjust_text

# Get PCA loadings
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

# Create a biplot
plt.figure(figsize=(10, 8))

# Scatter plot of PCA results colored by clusters
plt.scatter(X_r[:, 0], X_r[:, 1], c=y_kmeans, s=50, cmap='viridis', label='Models')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, label='Centroids')

# Identify top 5 features based on loadings
top_indices = np.argsort(np.abs(loadings[:, 0]))[-5:]  # Top 2 features for PC1
top_indices = top_indices[np.argsort(np.abs(loadings[top_indices, 1]))]  # Sort by PC2 loadings

scaling_factor = 4
texts = []  # List to collect the text objects

for i in top_indices:
    # Create an arrow with arrowhead
    arrow = FancyArrowPatch((0, 0), (loadings[i, 0] * scaling_factor, loadings[i, 1] * scaling_factor),color='r', alpha=0.5, mutation_scale=10, arrowstyle='->')
    plt.gca().add_patch(arrow)
    # Place the label initially
    text = plt.gca().text(loadings[i, 0] * scaling_factor, loadings[i, 1] * scaling_factor, df.columns[i], color='r')
    
    # Append the text to the list for later adjustment
    texts.append(text)

# Automatically adjust the text positions to avoid overlap
adjust_text(texts)

#Plot the decision boundaries
# Create a mesh grid over the PCA-reduced space
x_min, x_max = X_r[:, 0].min() - 1, X_r[:, 0].max() + 1
y_min, y_max = X_r[:, 1].min() - 1, X_r[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05),
                     np.arange(y_min, y_max, 0.05))

# Predict the cluster labels for each point in the mesh
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the cluster boundaries using contourf
plt.contourf(xx, yy, Z, alpha=0.3, cmap='viridis')

plt.title('PCA Biplot with Top 5 Features and K-means Clustering')
# Set axis limits to center (0, 0)
plt.xlim([-15, 20])  # Adjust these limits as necessary
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.axhline(0, color='grey', lw=0.5, ls='--')
plt.axvline(0, color='grey', lw=0.5, ls='--')
plt.grid()
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

# Perform hierarchical clustering on the PCA result
linked = linkage(X_r, method='ward')

plt.figure(figsize=(10, 7))
dendrogram(linked, labels=species)
plt.title('Hierarchical Clustering of Microbial Species by PCA')
plt.show()

# %% [markdown]
# ### Handling NA values using a masked array

# %%
from sklearn.decomposition import PCA
import numpy.ma as ma

species = df.index 

# Create a masked array, where NaNs are masked
masked_array = ma.masked_invalid(df.values)

# Initialize PCA
pca = PCA(n_components=2)  # Adjust n_components as needed

# Compute the mean along valid (non-masked) values, row-wise
# Masked values (NaNs) will be ignored in this calculation
masked_mean_centered = masked_array - masked_array.mean(axis=0)

# Standardize by dividing by the standard deviation
# Only consider non-masked values for standard deviation
std_dev = np.ma.std(masked_array, axis=0)

# Standardize without affecting NaN values
standardized_data = mean_centered / std_dev

# Fit PCA to the data, ignoring masked NaN values
# PCA will now ignore NaNs and work with the valid data
pca_result = pca.fit_transform(standardized_data.filled(0))  # Filling with 0 for calculation

# Create the scatter plot
plt.figure(figsize=(10, 8))
colors = plt.cm.get_cmap('tab10', len(species.unique()))  # Get a color map

# Plot each species using the unique species names directly
for i, name in enumerate(species.unique()):
    plt.scatter(pca_result[species == name, 0], pca_result[species == name, 1], color=colors(i), label=name)

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust this to move the legend
# Set axis limits to center (0, 0)
plt.xlim([-15, 20])  # Adjust these limits as necessary
plt.title('PCA of Dataset with Species as Index')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Show the plot
plt.show()

# %%
# Get the principal components
components = pca.components_  # Shape: (n_components, n_features)

# Get the explained variance
explained_variance = pca.explained_variance_ratio_

# Create a DataFrame to show loadings
loadings_df = pd.DataFrame(components.T, columns=[f'PC{i+1}' for i in range(components.shape[0])], index=df.columns)
print(loadings_df)
# Out:
#                              PC1           PC2
# EX_4abut(e)        -7.325533e-04  3.152441e-02
# EX_ac(e)            2.904796e-02  7.277887e-02
# EX_acald(e)        -9.678066e-02  5.661929e-02
# EX_adocbl(e)       -8.104246e-17 -3.660122e-17
# EX_ala_L(e)        -1.402284e-01 -3.770528e-02
# EX_alaasp(e)       -8.640332e-02  1.792138e-02
# EX_alagln(e)       -1.208062e-01 -8.129756e-02
# EX_alaglu(e)       -1.792492e-17 -6.951413e-17
# EX_alagly(e)        3.206912e-17  6.975198e-17
# EX_alahis(e)        7.697541e-02  1.822866e-01
# EX_alaleu(e)       -5.186788e-03 -1.056738e-01
# EX_alathr(e)       -2.166795e-02 -1.174686e-01
# EX_arab_L(e)       -0.000000e+00  0.000000e+00
# EX_arg_L(e)         1.129111e-01  7.394241e-02
# EX_arsenb(e)       -0.000000e+00  0.000000e+00
# EX_asn_L(e)        -4.278207e-02  1.524652e-01
# EX_aso3(e)         -0.000000e+00  0.000000e+00
# EX_aso4(e)         -0.000000e+00  0.000000e+00
# EX_asp_L(e)         1.258824e-01 -5.898985e-02
# ...

# %%
# Define the number of components
n_components = 2

# Convert DataFrame to NumPy array
X = np.ma.masked_invalid(df.values)

# Step 1: Mean Center the Data (only for non-NaN values)
means = np.ma.mean(X, axis=0)
X_centered = X - means

# Step 2: Standardize the Data (only for non-NaN values)
std_devs = np.ma.std(X, axis=0)
std_devs[std_devs == 0] = 1  # Avoid division by zero
X_standardized = X_centered / std_devs

# Step 3: Compute the Covariance Matrix
# Ensure only valid (non-masked) values are considered for covariance calculation
cov_matrix = np.ma.cov(X_standardized, rowvar=False)

# Step 4: Eigenvalue Decomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Sort the eigenvalues and eigenvectors in descending order
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# Step 5: Transform the Data
W = eigenvectors[:, :n_components]

# Create a valid transformed array to store results
X_transformed = np.full((X.shape[0], n_components), np.nan)  # Initialize with NaNs

# Perform the transformation for rows, ignoring NaN values in individual cells
for i in range(X.shape[0]):
    valid_mask = ~np.isnan(X_standardized[i])  # Identify valid (non-NaN) cells in the row
    valid_values = X_standardized[i][valid_mask]  # Select valid values from the row
    valid_weights = W[valid_mask, :]  # Select corresponding weights (columns) from W

    # Perform the transformation only with valid values
    X_transformed[i] = np.dot(valid_values, valid_weights)

# Print transformed data to check for NaNs
print("X Transformed:\n", X_transformed)
# Out:
# X Transformed:
#  [[ -0.09163505  -2.24737844]
#  [ -3.16937836  -1.25422855]
#  [  1.38859158  -6.36737301]
#  [ -4.0460284    3.22682704]
#  [ -7.53981847   2.95240741]
#  [  1.69038191 -11.09806663]
#  [  1.85515123   3.43046367]
#  [  0.56088433   3.93104208]
#  [  7.44963388   3.31721296]
#  [  1.90221734   4.10909348]]
# C:\Users\User\anaconda3\envs\Cobra\lib\site-packages\ipykernel_launcher.py:41: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
species = df.index

# Create the scatter plot
plt.figure(figsize=(10, 8))
colors = plt.cm.get_cmap('tab10', len(species.unique()))  # Get a color map

# Plot each species using the unique species names directly
for i, name in enumerate(species.unique()):
    plt.scatter(X_transformed[species == name, 0], X_transformed[species == name, 1], color=colors(i), label=name)

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Adjust this to move the legend
# Set axis limits to center (0, 0)
plt.xlim([-15, 20])  # Adjust these limits as necessary
plt.title('PCA of Dataset with Species as Index')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Show the plot
plt.show()

# %%
from sklearn.cluster import KMeans

# Performing K-means clustering
n_clusters = 4  # Set the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
y_kmeans = kmeans.fit_predict(X_transformed)

# Step 2: Create the plot
plt.figure(figsize=(10, 8))
plt.scatter(X_transformed[:, 0], X_transformed[:, 1], c=y_kmeans, s=50, cmap='viridis')  # Clustered points
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, label='Centroids')  # Cluster centers

# Step 3: Add titles and labels
plt.title('K-means Clustering on PCA Results')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Set axis limits to center (0, 0)
plt.xlim([-15, 20])  # Adjust these limits as necessary
plt.legend()
plt.grid()
plt.show()

# %%
from matplotlib.patches import FancyArrowPatch
from adjustText import adjust_text

# Get PCA loadings
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

# Create a biplot
plt.figure(figsize=(10, 8))

# Scatter plot of PCA results colored by clusters
plt.scatter(X_transformed[:, 0], X_transformed[:, 1], c=y_kmeans, s=50, cmap='viridis', label='Models')

# Plot cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, label='Centroids')

# Identify top 5 features based on loadings
top_indices = np.argsort(np.abs(loadings[:, 0]))[-5:]  # Top 2 features for PC1
top_indices = top_indices[np.argsort(np.abs(loadings[top_indices, 1]))]  # Sort by PC2 loadings

scaling_factor = 4
texts = []  # List to collect the text objects

for i in top_indices:
    # Create an arrow with arrowhead
    arrow = FancyArrowPatch((0, 0), (loadings[i, 0] * scaling_factor, loadings[i, 1] * scaling_factor),color='r', alpha=0.5, mutation_scale=10, arrowstyle='->')
    plt.gca().add_patch(arrow)
    # Place the label initially
    text = plt.gca().text(loadings[i, 0] * scaling_factor, loadings[i, 1] * scaling_factor, df.columns[i], color='r')
    
    # Append the text to the list for later adjustment
    texts.append(text)

# Automatically adjust the text positions to avoid overlap
adjust_text(texts)


plt.title('PCA Biplot with Top 5 Features and K-means Clustering')
# Set axis limits to center (0, 0)
plt.xlim([-15, 20])  # Adjust these limits as necessary
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.axhline(0, color='grey', lw=0.5, ls='--')
plt.axvline(0, color='grey', lw=0.5, ls='--')
plt.grid()
plt.show()
